# %%
import sys
print(sys.version)

# %%
pip install google-generativeai

# %%
import os
os.environ.setdefault('API_KEY', 'AIzaSyB7vkUxzqoAVmXWwzrPkRgHyJ6ZIfsQr-w')
#確認API有寫到os.environ 當中
'API_KEY' in os.environ

# %%
pip show google-generativeai

# %%
# %%time
import google.generativeai as genai
import os

genai.configure(api_key=os.environ['API_KEY'])


#temperature controls the randomness of the output. Use higher values for more creative responses, 
#and lower values for more deterministic responses. Values can range from [0.0, 2.0].
#maxOutputTokens sets the maximum number of tokens to include in a candidate.

model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(
        max_output_tokens=2000,
        temperature=2.0,
    ))

response = model.generate_content('你可以做甚麼')

print(response.text)
# Out:
# 作为一个大型语言模型，我拥有多种功能，可以帮助你完成各种任务。以下列举一些我可以做的事情：
#
# **信息获取和整理:**
#
# * **提供信息：**我可以提供各种主题的信息，从历史事件到科学理论，从流行文化到技术发展。
# * **回答问题：**我可以回答你提出的各种问题，无论其简单或复杂。
# * **总结文本：**我可以简要概述长篇文章或网页，帮助你快速理解主要内容。
# * **比较和对比：**我可以比较和对比不同事物，例如产品、书籍或理论。
# * **翻译语言：**我可以将文本翻译成不同的语言。
#
# **内容创作和生成:**
#
# * **撰写故事：**我可以根据你的指示编写故事，无论是科幻、奇幻还是现实主义风格。
# * **创作诗歌：**我可以生成不同形式和风格的诗歌。
# * **编写邮件和信件：**我可以帮助你撰写正式或非正式的邮件和信件。
# * **生成代码：**我可以根据你的指示生成不同的编程代码。
# * **生成表格和列表：**我可以创建表格、列表和清单。
#
# **辅助和娱乐:**
#
# * **提供娱乐：**我可以讲笑话、玩游戏，并提供一些有趣的事实。
# * **提供建议：**我可以根据你的需要提供各种建议，例如书籍推荐、餐厅推荐、旅行计划等等。
# * **帮助你完成任务：**我可以帮你设定提醒、生成待办事项列表，以及执行其他简单任务。
# * **学习新技能：**我可以帮你学习新的技能，例如编程语言或外语。
#
# 总的来说，我是一个全面的语言模型，可以满足你各种各样的需求。如果你需要任何帮助，请随时提问！
#
# CPU times: total: 219 ms
# Wall time: 5.27 s

# %%
pip install Pillow
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\lib\site-packages (9.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import Image
from IPython.core.display import HTML


model = genai.GenerativeModel('gemini-1.5-flash')
img = Image('img/food.jpg')
img

# %%
response = model.generate_content(img)

print(response.text)
# Out:
# The image shows two glass containers filled with food.  The left container contains rice, broccoli, carrots, and red peppers. The right container contains rice, broccoli, and chicken. Both containers are sitting on a grey surface.

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])
chat

# %%
#不會停止的迴圈讓使用者可以不停地跟gemini用文字互動，如果不按下停止鍵的話其他Cell會不能使用
while True:
    ans = input('輸入文字：')
    response = chat.send_message(ans)
    print(response.text)

# %%
chat.history

# %%
pip install flask

# %%
#用Flask刻網頁頁面讓使用者跟gemini互動

from werkzeug.wrappers import Request, Response
from flask import Flask, render_template, request

import google.generativeai as genai
import os
from werkzeug.utils import secure_filename

genai.configure(api_key=os.environ['API_KEY'])

model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])

import glob
from IPython.display import Image
from IPython.core.display import HTML

app = Flask(__name__)

#處理文字邏輯
gemini_ans = ''

@app.route('/', methods=['GET', 'POST'])
def index():
    
    if request.method == 'POST':
        gemini_get = request.form.get("gemini_get")
        #print("從gemini_get得來的text: ",gemini_get)
        
        gemini_response = chat.send_message(gemini_get)
        print("從gemini 那邊拿到的回答", gemini_response.text)
        
        global gemini_ans
        gemini_ans = gemini_response.text
        print("傳到web上的資訊:", gemini_ans)
        
        
    return render_template('index.html', gemini_ans = gemini_ans)


#處理照片邏輯
gemini_img_ans = ''

@app.route("/upload", methods=['GET', 'POST'])
def upload_file():
    if request.method == 'POST':
        if 'photo' not in request.files:
            print('沒有照片')
        file = request.files['photo']
        if file.filename == '':
            print('沒有選擇照片') 
        if file:
            file.save(f"./img_save/{file.filename}")
            print('照片上傳成功')


            # 設定圖片文件夾路徑
            folder_path = './img_save'

            # 獲取文件夾中所有圖片的列表
            image_files = glob.glob(f"{folder_path}/*")
            
            
            # 找到建立時間最晚的圖片
            latest_image = max(image_files, key=os.path.getctime)
            print(f"Latest image: {latest_image}")
            
            
            img = Image(filename=latest_image)
            display(img)
            
            response_img = model.generate_content(["照片裡面有甚麼?", img])

            print(response_img.text)
            
            global gemini_img_ans
            gemini_img_ans = response_img.text
        
        

    return render_template('upload.html',gemini_img_ans = gemini_img_ans )

if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9001, app)
# Out:
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:9001
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Jul/2024 17:02:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 17:02:39] "GET /style/styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jul/2024 17:11:03] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 17:11:03] "GET /style/styles.css HTTP/1.1" 404 -
# 從gemini 那邊拿到的回答 我是一個大型語言模型，由 Google 訓練。我可以做很多事情，以下是一些例子：
#
# **語言相關:**
#
# * **生成文本:** 我可以根據您的要求生成各種文本，例如故事、詩歌、文章、電子郵件、程式碼等。
# * **翻譯語言:** 我可以將文字從一種語言翻譯成另一種語言。
# * **回答問題:** 我可以根據我的訓練數據，回答您的問題。
# * **總結文本:** 我可以總結長篇文章的重點。
# * **生成創意內容:** 我可以協助您進行頭腦風暴，並提供創意點子。
#
# **其他功能:**
#
# * **提供資訊:** 我可以根據您的要求提供關於各個主題的資訊。
# * **玩遊戲:** 我可以與您玩一些簡單的文字遊戲。
# * **協助您完成任務:** 我可以提供步驟指南，協助您完成任務。
# * **娛樂您:** 我可以講笑話、講故事或分享有趣的事實。
#
# **局限性:**
#
# * 我並非人類，無法擁有情感或意識。
# * 我的知識和能力受限於我所接受的訓練數據。
# * 我無法替換人類的判斷力和專業知識。
#
# **總之，我是一個強大的工具，可以協助您完成各種任務，但請記住我的局限性，並在需要時尋求人類的協助。**
#
# 請問您想讓我做些什麼呢？
#
# 傳到web上的資訊: 我是一個大型語言模型，由 Google 訓練。我可以做很多事情，以下是一些例子：
#
# **語言相關:**
#
# * **生成文本:** 我可以根據您的要求生成各種文本，例如故事、詩歌、文章、電子郵件、程式碼等。
# * **翻譯語言:** 我可以將文字從一種語言翻譯成另一種語言。
# * **回答問題:** 我可以根據我的訓練數據，回答您的問題。
# * **總結文本:** 我可以總結長篇文章的重點。
# * **生成創意內容:** 我可以協助您進行頭腦風暴，並提供創意點子。
#
# **其他功能:**
#
# * **提供資訊:** 我可以根據您的要求提供關於各個主題的資訊。
# * **玩遊戲:** 我可以與您玩一些簡單的文字遊戲。
# * **協助您完成任務:** 我可以提供步驟指南，協助您完成任務。
# * **娛樂您:** 我可以講笑話、講故事或分享有趣的事實。
#
# **局限性:**
#
# * 我並非人類，無法擁有情感或意識。
# * 我的知識和能力受限於我所接受的訓練數據。
# * 我無法替換人類的判斷力和專業知識。
#
# **總之，我是一個強大的工具，可以協助您完成各種任務，但請記住我的局限性，並在需要時尋求人類的協助。**
#
# 請問您想讓我做些什麼呢？
# 127.0.0.1 - - [25/Jul/2024 17:11:25] "GET /upload HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 17:11:25] "GET /style/styles.css HTTP/1.1" 404 -
# 照片上傳成功
# Latest image: ./img_save\Faker.png
# 127.0.0.1 - - [25/Jul/2024 17:11:35] "POST /upload HTTP/1.1" 200 -
# 這張照片中是一位戴著金牌的年輕男性運動員，他身穿白色夾克，上面繡著韓國國旗和 2022 漢城奧運會的標誌。 他看起來很靦腆或羞怯。 他站在另一位身穿白色夾克的男性運動員旁邊，但他被裁掉了。 在照片的背景中，可以看見一場運動賽事，觀眾們都坐在觀眾席上。
# 127.0.0.1 - - [25/Jul/2024 17:11:36] "GET /style/styles.css HTTP/1.1" 404 -
